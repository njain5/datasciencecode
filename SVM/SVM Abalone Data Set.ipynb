# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %%
df=pd.read_csv("abalone.csv")

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.head()
# Out:
#   Sex  Length    Diameter  Height   Whole weight     Shucked weight  \
# 0   M     0.455     0.365    0.095           0.5140          0.2245
# 1   M     0.350     0.265    0.090           0.2255          0.0995
# 2   F     0.530     0.420    0.135           0.6770          0.2565
# 3   M     0.440     0.365    0.125           0.5160          0.2155
# 4   I     0.330     0.255    0.080           0.2050          0.0895
#
#    Viscera weight   Shell weight     Rings
# 0           0.1010            0.150     15
# 1           0.0485            0.070      7
# 2           0.1415            0.210      9
# 3           0.1140            0.155     10
# 4           0.0395            0.055      7

# %%
# Scatter Plot
# color pallete- http://seaborn.pydata.org/tutorial/color_palettes.html
import seaborn as sns
sns.pairplot(df, hue="Sex", palette="husl", size =5)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df.corr()
# Out:
#                  Length    Diameter   Height   Whole weight     \
# Length           1.000000  0.986812  0.827554         0.925261
# Diameter         0.986812  1.000000  0.833684         0.925452
# Height           0.827554  0.833684  1.000000         0.819221
# Whole weight     0.925261  0.925452  0.819221         1.000000
# Shucked weight   0.897914  0.893162  0.774972         0.969405
# Viscera weight   0.903018  0.899724  0.798319         0.966375
# Shell weight     0.897706  0.905330  0.817338         0.955355
# Rings            0.556720  0.574660  0.557467         0.540390
#
#                  Shucked weight  Viscera weight   Shell weight        Rings
# Length                 0.897914         0.903018         0.897706  0.556720
# Diameter               0.893162         0.899724         0.905330  0.574660
# Height                 0.774972         0.798319         0.817338  0.557467
# Whole weight           0.969405         0.966375         0.955355  0.540390
# Shucked weight         1.000000         0.931961         0.882617  0.420884
# Viscera weight         0.931961         1.000000         0.907656  0.503819
# Shell weight           0.882617         0.907656         1.000000  0.627574
# Rings                  0.420884         0.503819         0.627574  1.000000

# %%
df.columns = [c.strip() for c in df.columns]

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
y=df.Sex
feature_cols = ['Length','Height','Shucked weight','Rings']
x=df[feature_cols]

# %%
x.head()
# Out:
#    Length  Height  Shucked weight  Rings
# 0   0.455   0.095          0.2245     15
# 1   0.350   0.090          0.0995      7
# 2   0.530   0.135          0.2565      9
# 3   0.440   0.125          0.2155     10
# 4   0.330   0.080          0.0895      7

# %%
x.corr()
# Out:
#                   Length    Height  Shucked weight     Rings
# Length          1.000000  0.827554        0.897914  0.556720
# Height          0.827554  1.000000        0.774972  0.557467
# Shucked weight  0.897914  0.774972        1.000000  0.420884
# Rings           0.556720  0.557467        0.420884  1.000000

# %% [markdown]
# # Standardizing the input

# %% [markdown]
# **Time for some preprocessing** - Observe how the 'Rings' column has integer values whereas every other column contains floating point numbers.

# %%
#Standardizing the input
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x_transformed=ss.fit_transform(x)
x = x_transformed

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.10,random_state=123)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3759, 4)
# (418, 4)
# (3759,)
# (418,)

# %% [markdown]
# # Logistic Regression

# %%
## Building the model
from sklearn.linear_model import LogisticRegression
log_reg=LogisticRegression()
log_model=log_reg.fit(x_train,y_train)
print(log_model)
# Out:
# LogisticRegression()

# %%
## Prediction with logistic regression model
log_prd=log_model.predict(x_test)
print(accuracy_score(y_test,log_prd))
print(confusion_matrix(y_test,log_prd))
print(classification_report(y_test,log_prd))
# Out:
# 0.5741626794258373
# [[ 46  18  54]
#  [ 13 110  14]
#  [ 45  34  84]]
#               precision    recall  f1-score   support
#
#            F       0.44      0.39      0.41       118
#            I       0.68      0.80      0.74       137
#            M       0.55      0.52      0.53       163
#
#     accuracy                           0.57       418
#    macro avg       0.56      0.57      0.56       418
# weighted avg       0.56      0.57      0.57       418

# %% [markdown]
# # SVC

# %%
#Prediction with SVC model
clf=SVC(kernel='linear', decision_function_shape='ovr')
model=clf.fit(x_train,y_train)
y_pred=model.predict(x_test)
clf
# Out:
# SVC(kernel='linear')

# %%
print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.569377990430622
# [[  8  18  92]
#  [  1 111  25]
#  [  9  35 119]]
#               precision    recall  f1-score   support
#
#            F       0.44      0.07      0.12       118
#            I       0.68      0.81      0.74       137
#            M       0.50      0.73      0.60       163
#
#     accuracy                           0.57       418
#    macro avg       0.54      0.54      0.48       418
# weighted avg       0.54      0.57      0.51       418

# %% [markdown]
# # Perform GridSearch

# %%
params={"kernel":('linear','rbf'),"C":[1,50,100],"gamma":[0.03,1,10],"decision_function_shape":('ovr','ovo')}## Please keep patience, It'll take long time

# %%
grid=GridSearchCV(clf,params)
grid_model=grid.fit(x_train,y_train)

# %%
grid_model.best_params_
# Out:
# {'C': 100, 'decision_function_shape': 'ovr', 'gamma': 0.03, 'kernel': 'rbf'}

# %%
grid_pred=grid_model.predict(x_test)

# %%
print(accuracy_score(y_test,grid_pred))
print(confusion_matrix(y_test,grid_pred))
print(classification_report(y_test,grid_pred))
# Out:
# 0.5861244019138756
# [[ 20  16  82]
#  [  6 109  22]
#  [ 15  32 116]]
#               precision    recall  f1-score   support
#
#            F       0.49      0.17      0.25       118
#            I       0.69      0.80      0.74       137
#            M       0.53      0.71      0.61       163
#
#     accuracy                           0.59       418
#    macro avg       0.57      0.56      0.53       418
# weighted avg       0.57      0.59      0.55       418

# %% [markdown]
# # Applying PCA

# %%
from sklearn.decomposition import PCA

pca_model = PCA(n_components=4)
pca_model.fit(x)
print (pca_model.explained_variance_ratio_)
#Plot the explained variance
plt.plot(pca_model.explained_variance_ratio_);
plt.xlabel('Principal Component');
plt.ylabel('Percentage Explained Variance');
# Out:
# [0.76284089 0.16049505 0.05517111 0.02149294]

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#Visualize coefficients using heat map
plt.figure(figsize=[25,5])
sns.heatmap(pca_model.components_[0:2,:],annot=True,cmap='viridis')
plt.yticks([0,1],["First component","Second component"],rotation=360,ha="right")
plt.xticks(range(len(feature_cols)),feature_cols,rotation=60,ha="left")
plt.xlabel("Feature")
plt.ylabel("Principal components")
# Out:
# Text(204.0, 0.5, 'Principal components')

# %%
x_pca = PCA(n_components=2)
#Build a PCA model with just the training data
train_pca = x_pca.fit_transform(x_train)
#Fit the test data to the above PCA model
test_pca = x_pca.fit_transform(x_test)

# %%
test_pca
# Out:
# array([[-3.75746374e+00, -1.61264928e-01],
#        [ 1.70479879e+00, -9.00232118e-01],
#        [-1.29414646e+00,  2.90220184e-01],
#        [ 6.95665161e-01, -5.02110555e-01],
#        [ 6.22197300e-01,  1.18838582e+00],
#        [-1.51934063e+00,  7.28931457e-01],
#        [ 1.44008765e+00, -2.89891927e-01],
#        [-2.80333509e-01, -8.48988579e-01],
#        [ 1.20126363e+00, -4.86411843e-02],
#        [ 1.89394119e+00, -8.41001410e-01],
#        [-1.99004751e+00, -1.33979860e-01],
#        [ 9.51363487e-01,  4.19206424e-01],
#        [-1.72193964e+00, -8.13755215e-02],
#        [-1.16181353e+00,  2.94412716e-01],
#        [-3.40651226e-01, -7.80676953e-02],
#        [ 1.50479384e+00, -6.07089057e-01],
#        [-1.97015591e+00,  2.37151400e-01],
#        [-1.27784035e+00, -6.46615582e-02],
#        [ 2.80212605e-01, -3.48924452e-03],
#        [-2.95889610e-01,  1.86919593e-01],
#        [ 3.41333536e+00,  1.98880138e+00],
#        [ 7.49939084e-01,  7.86449588e-01],
#        [ 2.64856320e+00, -1.11975186e+00],
#        [ 1.36595271e+00, -2.60649750e-01],
#        [ 2.91030348e+00, -3.74468009e-01],
#        [-3.52300210e+00, -2.34399577e-01],
#        [-2.74214831e+00, -1.06023058e-01],
#        [ 7.74254816e-01, -9.47807312e-01],
#        [ 9.86818432e-02,  5.99346654e-02],
#        [ 3.06805623e+00,  8.45997451e-02],
#        [-7.68771851e-01,  4.07843947e-02],
#        [ 7.72704490e-01, -3.15649341e-01],
#        [ 1.75809723e+00, -1.98489158e-02],
#        [-5.71001648e-01, -1.46912087e-02],
#        [-3.70058567e+00, -1.03726194e-01],
#        [ 3.13210851e+00, -7.70433116e-01],
#        [ 1.70812372e+00, -7.47750464e-01],
#        [-4.46487314e-01,  5.58453448e-02],
#        [ 1.52132156e+00, -5.86068356e-01],
#        [-6.02026836e-01, -2.73003658e-01],
#        [-3.74320844e+00,  4.58925741e-01],
#        [-2.27932026e+00, -6.70572952e-01]])

# %%
# train a logistic regression model on the training set
from sklearn.linear_model import LogisticRegression

# instantiate model
pcalg = LogisticRegression(C=1e42)

# fit model
pcalg.fit(train_pca, y_train)
# Out:
# LogisticRegression(C=1e+42)

# %%
# make class predictions for the testing set
y_pred_class_pca = pcalg.predict(test_pca)

# %%
# calculate accuracy
from sklearn import metrics
print(metrics.accuracy_score(y_test, y_pred_class_pca))
print (metrics.precision_recall_fscore_support(y_test, y_pred_class_pca, average='weighted'))
print(metrics.confusion_matrix(y_test,y_pred_class_pca))
# Out:
# 0.562200956937799
# (0.5489159891598916, 0.562200956937799, 0.5433274769952536, None)
# [[ 28  16  74]
#  [  3 105  29]
#  [ 32  29 102]]

# %%
#Prediction with SVC model
clf=SVC(kernel='linear',C=164, decision_function_shape='ovr')
model=clf.fit(train_pca,y_train)
y_pred=model.predict(test_pca)
clf
# Out:
# SVC(C=164, kernel='linear')

# %%
print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.569377990430622
# [[  0  16 102]
#  [  0 104  33]
#  [  0  29 134]]
#               precision    recall  f1-score   support
#
#            F       0.00      0.00      0.00       118
#            I       0.70      0.76      0.73       137
#            M       0.50      0.82      0.62       163
#
#     accuracy                           0.57       418
#    macro avg       0.40      0.53      0.45       418
# weighted avg       0.42      0.57      0.48       418
# C:\Users\Nikhil Jain\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
